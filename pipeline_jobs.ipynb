# %%
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core import PipelineData

# %%
input_dataset = ws.datasets.get('Defaults')
data_folder = PipelineData()

# %%
data_prep_step = PythonScriptStep(name='data preparation',
                                  source_directory='.',
                                  script_name = 'data_preparation.py',
                                  inputs=[input_dataset.as_named_input('raw_data')],
                                  outputs=[data_folder])

# %%
from azureml.core import Workspace, Dataset, Datastore, Experiment, Environment, ScriptRunConfig, Run
from azureml.core.environment import CondaDependencies

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import logging
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from statsmodels.tsa.arima.model import ARIMA
#       2 from sklearn.metrics import mean_squared_error
#       3 import pandas as pd
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py:21
#      19 from statsmodels.tsa.arima.estimators.yule_walker import yule_walker
#      20 from statsmodels.tsa.arima.estimators.burg import burg
# ---> 21 from statsmodels.tsa.arima.estimators.hannan_rissanen import hannan_rissanen
#      22 from statsmodels.tsa.arima.estimators.innovations import (
#      23     innovations, innovations_mle)
#      24 from statsmodels.tsa.arima.estimators.gls import gls as estimate_gls
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/statsmodels/tsa/arima/estimators/hannan_rissanen.py:9
#       1 """
#       2 Hannan-Rissanen procedure for estimating ARMA(p,q) model parameters.
#       3
#       4 Author: Chad Fulton
#       5 License: BSD-3
#       6 """
#       7 import numpy as np
# ----> 9 from scipy.signal import lfilter
#      10 from statsmodels.tools.tools import Bunch
#      11 from statsmodels.regression.linear_model import OLS, yule_walker
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/scipy/signal/__init__.py:312
#     310 from ._waveforms import *
#     311 from ._max_len_seq import max_len_seq
# --> 312 from ._upfirdn import upfirdn
#     314 from ._spline import (  # noqa: F401
#     315     cspline2d,
#     316     qspline2d,
#    (...)
#     319     symiirorder2,
#     320 )
#     322 from ._bsplines import *
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/scipy/signal/_upfirdn.py:36
#       1 # Code adapted from "upfirdn" python library with permission:
#       2 #
#       3 # Copyright (c) 2009, Motorola, Inc
#    (...)
#      31 # NEGLIGENCE OR OTHERWISE) ARISING IN ANY WAY OUT OF THE USE OF THIS
#      32 # SOFTWARE, EVEN IF ADVISED OF THE POSSIBILITY OF SUCH DAMAGE.
#      34 import numpy as np
# ---> 36 from ._upfirdn_apply import _output_len, _apply, mode_enum
#      38 __all__ = ['upfirdn', '_output_len']
#      40 _upfirdn_modes = [
#      41     'constant', 'wrap', 'edge', 'smooth', 'symmetric', 'reflect',
#      42     'antisymmetric', 'antireflect', 'line',
#      43 ]
#
# File <frozen importlib._bootstrap>:398, in parent(self)
#
# KeyboardInterrupt:

# %%
ws = Workspace.from_config()
az_store = Datastore.get(ws, "azure_sdk_nse_blob")
az_dataset = Dataset.get_by_name(ws, "final_data_stocks")
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
# Import the necessary Azure ML classes
# Create/access the experiment from the workspace
new_experiment = Experiment(workspace=ws, name="Training_Script_reliance")

# -------------------------------------------------
# Create custom environment
# -------------------------------------------------
# Define the environment
myenv = Environment(name="MyEnvironment")

# Create the dependencies object with necessary packages (such as scikit-learn, pandas, statsmodels)
myenv_dep = CondaDependencies.create(
    conda_packages=['scikit-learn', 'statsmodels', 'pandas', 'numpy']
)

# Set the environment dependencies
myenv.python.conda_dependencies = myenv_dep

# Register the environment
myenv.register(ws)
# -------------------------------------------------

# Create a script configuration using the custom environment
script_config = ScriptRunConfig(
    source_directory=".",  # The directory where your script is located
    script="reliance_train.py",  # The training script to run
    environment=myenv  # The custom environment for the run
)
import azureml._restclient.snapshots_client
azureml._restclient.snapshots_client.SNAPSHOT_MAX_SIZE_BYTES = 3000000000

# %%
# Monitor and wait for the run to complete
# Submit a new run using the ScriptRunConfig
new_run = new_experiment.submit(config=script_config)
new_run.wait_for_completion(show_output=True)
# Out:
# RunId: Training_Script_reliance_1738244642_37fa8c01
# Web View: https://ml.azure.com/runs/Training_Script_reliance_1738244642_37fa8c01?wsid=/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourcegroups/mlproject/workspaces/mlprojectexperiments&tid=47855545-00bb-4800-a65f-e79104ec0fc4
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6b34dd310>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6b34ddf70>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6b316aa30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6b34e9550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6933dbac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6933dbaf0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6a192ddf0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6a192dfa0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6a1962340>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6933f3610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6a18d1070>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6a1b7d7c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:953, in getaddrinfo(host, port, family, type, proto, flags)
#     952 addrlist = []
# --> 953 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     954     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connectionpool.py:1061, in HTTPSConnectionPool._validate_conn(self, conn)
#    1060 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1061     conn.connect()
#    1063 if not conn.is_verified:
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fe6b34e9eb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connectionpool.py:830, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     827     log.warning(
#     828         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     829     )
# --> 830     return self.urlopen(
#     831         method,
#     832         url,
#     833         body,
#     834         headers,
#     835         retries,
#     836         redirect,
#     837         assert_same_host,
#     838         timeout=timeout,
#     839         pool_timeout=pool_timeout,
#     840         release_conn=release_conn,
#     841         chunked=chunked,
#     842         body_pos=body_pos,
#     843         **response_kw
#     844     )
#     846 # Handle redirect?
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connectionpool.py:830, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     827     log.warning(
#     828         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     829     )
# --> 830     return self.urlopen(
#     831         method,
#     832         url,
#     833         body,
#     834         headers,
#     835         retries,
#     836         redirect,
#     837         assert_same_host,
#     838         timeout=timeout,
#     839         pool_timeout=pool_timeout,
#     840         release_conn=release_conn,
#     841         chunked=chunked,
#     842         body_pos=body_pos,
#     843         **response_kw
#     844     )
#     846 # Handle redirect?
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connectionpool.py:830, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     827     log.warning(
#     828         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     829     )
# --> 830     return self.urlopen(
#     831         method,
#     832         url,
#     833         body,
#     834         headers,
#     835         retries,
#     836         redirect,
#     837         assert_same_host,
#     838         timeout=timeout,
#     839         pool_timeout=pool_timeout,
#     840         release_conn=release_conn,
#     841         chunked=chunked,
#     842         body_pos=body_pos,
#     843         **response_kw
#     844     )
#     846 # Handle redirect?
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/connectionpool.py:802, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     800     e = ProtocolError("Connection aborted.", e)
# --> 802 retries = retries.increment(
#     803     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     804 )
#     805 retries.sleep()
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/urllib3/util/retry.py:594, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     593 if new_retry.is_exhausted():
# --> 594     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     596 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='southindia.api.azureml.ms', port=443): Max retries exceeded with url: /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6b34e9eb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/universal_http/requests.py:139, in BasicRequestsHTTPSender.send(self, request, **kwargs)
#     138 try:
# --> 139     response = session.request(
#     140         request.method,
#     141         request.url,
#     142         **kwargs)
#     143 except requests.RequestException as err:
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='southindia.api.azureml.ms', port=443): Max retries exceeded with url: /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6b34e9eb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ClientRequestError                        Traceback (most recent call last)
# Cell In[9], line 4
#       1 # Monitor and wait for the run to complete
#       2 # Submit a new run using the ScriptRunConfig
#       3 new_run = new_experiment.submit(config=script_config)
# ----> 4 new_run.wait_for_completion(show_output=True)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/core/run.py:849, in Run.wait_for_completion(self, show_output, wait_post_processing, raise_on_error)
#     847 if show_output:
#     848     try:
# --> 849         self._stream_run_output(
#     850             file_handle=sys.stdout,
#     851             wait_post_processing=wait_post_processing,
#     852             raise_on_error=raise_on_error)
#     853         return self.get_details()
#     854     except KeyboardInterrupt:
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/core/run.py:1049, in Run._stream_run_output(self, file_handle, wait_post_processing, raise_on_error)
#    1047 file_handle.flush()
#    1048 time.sleep(Run._wait_before_polling(time.time() - poll_start_time))
# -> 1049 self._current_details = self.get_details()  # TODO use FileWatcher
#    1051 # Check whether there is a higher priority log than the one we are currently streaming (current_log)
#    1052 available_logs = self._get_logs(self._current_details)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/core/run.py:1265, in Run.get_details(self)
#    1199 def get_details(self):
#    1200     """Get the definition, status information, current log files, and other details of the run.
#    1201
#    1202     .. remarks::
#    (...)
#    1263     :rtype: dict[str, str]
#    1264     """
# -> 1265     details = self._client.get_runstatus().as_dict(key_transformer=camel_case_transformer)
#    1266     # backfill common runtime logs as RH should no longer be proxying these
#    1267     details["logFiles"].update(self._get_common_runtime_logs())
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_run_impl/run_history_facade.py:194, in RunHistoryFacade.get_runstatus(self)
#     193 def get_runstatus(self):
# --> 194     run_status = self.run.get_runstatus()
#     195     self.update_cached_status(run_status.status)
#     196     return run_status
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/run_client.py:107, in RunClient.get_runstatus(self, caller, custom_headers, is_async)
#      89 """
#      90 Get status details of a run by its run_id
#      91 :param is_async: execute request asynchronously
#    (...)
#     102     azureml._async.AsyncTask (is_async is True)
#     103 """
#     104 kwargs = _generate_client_kwargs(
#     105     is_async=is_async, caller=caller, custom_headers=custom_headers)
# --> 107 return self._execute_with_run_arguments(self._client.run.get_details, **kwargs)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/run_client.py:564, in RunClient._execute_with_run_arguments(self, func, *args, **kwargs)
#     563 def _execute_with_run_arguments(self, func, *args, **kwargs):
# --> 564     return self._execute_with_arguments(func, copy.deepcopy(self._run_arguments), *args, **kwargs)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/clientbase.py:590, in ClientBase._execute_with_arguments(self, func, args_list, *args, **kwargs)
#     588         return self._call_paginated_api(func, *args_list, **kwargs)
#     589     else:
# --> 590         return self._call_api(func, *args_list, **kwargs)
#     591 except ErrorResponseException as e:
#     592     raise ServiceException(e)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/clientbase.py:245, in ClientBase._call_api(self, func, *args, **kwargs)
#     243     return AsyncTask(future, _ident=ident, _parent_logger=self._logger)
#     244 else:
# --> 245     return self._execute_with_base_arguments(func, *args, **kwargs)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/clientbase.py:334, in ClientBase._execute_with_base_arguments(self, func, *args, **kwargs)
#     332 back_off = self.backoff_factor
#     333 total_retry = 0 if self.retries < 0 else self.retries
# --> 334 return ClientBase._execute_func_internal(
#     335     back_off, total_retry, self._logger, func, _noop_reset, *args, **kwargs)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/clientbase.py:368, in ClientBase._execute_func_internal(cls, back_off, total_retry, logger, func, reset_func, *args, **kwargs)
#     366     return response
#     367 except Exception as error:
# --> 368     left_retry = cls._handle_retry(back_off, left_retry, total_retry, error, logger, func)
#     370 reset_func(*args, **kwargs)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/clientbase.py:400, in ClientBase._handle_retry(cls, back_off, left_retry, total_retry, error, logger, func)
#     398 status_code = None
#     399 if left_retry == 0:
# --> 400     raise error
#     401 elif isinstance(error, HttpOperationError) or isinstance(error, HTTPError):
#     402     status_code = error.response.status_code
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/clientbase.py:359, in ClientBase._execute_func_internal(cls, back_off, total_retry, logger, func, reset_func, *args, **kwargs)
#     357 try:
#     358     logger.debug("ClientBase: Calling {} with url {}".format(func_name, func_url))
# --> 359     response = func(*args, **kwargs)
#     360     if (isinstance(response, Response) and cls._is_retryable_status_code(response.status_code)
#     361             and left_retry > 0):
#     362         # This is the handle the error case 1. response.raise_for_status only throws HTTPError exception.
#     363         # if the status_code is retryable and it is not the last retry, then the exception is thrown.
#     364         # Otherwise, we will return the response directly.
#     365         response.raise_for_status()
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/_restclient/operations/run_operations.py:299, in RunOperations.get_details(self, subscription_id, resource_group_name, workspace_name, experiment_name, run_id, custom_headers, raw, **operation_config)
#     297 # Construct and send request
#     298 request = self._client.get(url, query_parameters)
# --> 299 response = self._client.send(request, header_parameters, stream=False, **operation_config)
#     301 if response.status_code not in [200]:
#     302     raise models.ErrorResponseException(self._deserialize, response)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/service_client.py:336, in ServiceClient.send(self, request, headers, content, **kwargs)
#     334 kwargs.setdefault('stream', True)
#     335 try:
# --> 336     pipeline_response = self.config.pipeline.run(request, **kwargs)
#     337     # There is too much thing that expects this method to return a "requests.Response"
#     338     # to break it in a compatible release.
#     339     # Also, to be pragmatic in the "sync" world "requests" rules anyway.
#     340     # However, attach the Universal HTTP response
#     341     # to get the streaming generator.
#     342     response = pipeline_response.http_response.internal_response
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/pipeline/__init__.py:197, in Pipeline.run(self, request, **kwargs)
#     195 pipeline_request = Request(request, context)  # type: Request[HTTPRequestType]
#     196 first_node = self._impl_policies[0] if self._impl_policies else self._sender
# --> 197 return first_node.send(pipeline_request, **kwargs)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/pipeline/__init__.py:150, in _SansIOHTTPPolicyRunner.send(self, request, **kwargs)
#     148 self._policy.on_request(request, **kwargs)
#     149 try:
# --> 150     response = self.next.send(request, **kwargs)
#     151 except Exception:
#     152     if not self._policy.on_exception(request, **kwargs):
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/pipeline/requests.py:72, in RequestsCredentialsPolicy.send(self, request, **kwargs)
#      70 try:
#      71     try:
# ---> 72         return self.next.send(request, **kwargs)
#      73     except (oauth2.rfc6749.errors.InvalidGrantError,
#      74             oauth2.rfc6749.errors.TokenExpiredError) as err:
#      75         error = "Token expired or is invalid. Attempting to refresh."
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/pipeline/requests.py:137, in RequestsPatchSession.send(self, request, **kwargs)
#     134         session.adapters[protocol].max_retries = max_retries
#     136 try:
# --> 137     return self.next.send(request, **kwargs)
#     138 finally:
#     139     if old_max_redirects:
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/pipeline/__init__.py:150, in _SansIOHTTPPolicyRunner.send(self, request, **kwargs)
#     148 self._policy.on_request(request, **kwargs)
#     149 try:
# --> 150     response = self.next.send(request, **kwargs)
#     151 except Exception:
#     152     if not self._policy.on_exception(request, **kwargs):
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/pipeline/requests.py:193, in PipelineRequestsHTTPSender.send(self, request, **kwargs)
#     188 if request.context.session is not self.driver.session:
#     189     kwargs['session'] = request.context.session
#     191 return Response(
#     192     request,
# --> 193     self.driver.send(request.http_request, **kwargs)
#     194 )
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/universal_http/requests.py:333, in RequestsHTTPSender.send(self, request, **kwargs)
#     314 """Send request object according to configuration.
#     315
#     316 Available kwargs:
#    (...)
#     330 :param ClientRequest request: The request object to be sent.
#     331 """
#     332 requests_kwargs = self._configure_send(request, **kwargs)
# --> 333 return super(RequestsHTTPSender, self).send(request, **requests_kwargs)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/universal_http/requests.py:145, in BasicRequestsHTTPSender.send(self, request, **kwargs)
#     143 except requests.RequestException as err:
#     144     msg = "Error occurred in request."
# --> 145     raise_with_traceback(ClientRequestError, msg, err)
#     147 return RequestsClientResponse(request, response)
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/exceptions.py:51, in raise_with_traceback(exception, message, *args, **kwargs)
#      49 error = exception(exc_msg, *args, **kwargs)
#      50 try:
# ---> 51     raise error.with_traceback(exc_traceback)
#      52 except AttributeError:
#      53     error.__traceback__ = exc_traceback
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/msrest/universal_http/requests.py:139, in BasicRequestsHTTPSender.send(self, request, **kwargs)
#     137 session = kwargs.pop('session', self.session)
#     138 try:
# --> 139     response = session.request(
#     140         request.method,
#     141         request.url,
#     142         **kwargs)
#     143 except requests.RequestException as err:
#     144     msg = "Error occurred in request."
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ClientRequestError: Error occurred in request., ConnectionError: HTTPSConnectionPool(host='southindia.api.azureml.ms', port=443): Max retries exceeded with url: /history/v1.0/subscriptions/a9be2bae-a7e2-4890-9232-48dc82eb3c71/resourceGroups/mlproject/providers/Microsoft.MachineLearningServices/workspaces/mlprojectexperiments/experiments/Training_Script_reliance/runs/Training_Script_reliance_1738244642_37fa8c01/details (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6b34e9eb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
new_experiment = Experiment(workspace=ws, name="Traning_script")
myenv = Environment(name="MyEnvironment")
myenv_dep = CondaDependencies.create(conda_packages=['scikit-Learn', 'statsmodels'])
myenv.python.conda_dependencies = myenv_dep
myenv.register(ws)
# Out:
# {
#     "assetId": "azureml://locations/southindia/workspaces/54d16ff2-8663-4b2f-883d-a81a7c18913f/environments/MyEnvironment/versions/1",
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20241202.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "buildContext": null,
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "MyEnvironment",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.9.12",
#                 {
#                     "pip": [
#                         "azureml-defaults~=1.59.0"
#                     ]
#                 },
#                 "scikit-Learn",
#                 "statsmodels"
#             ],
#             "name": "project_environment"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "1"
# }

# %%
script_config = ScriptRunConfig(source_directory='.',
                script="train_script.ipynb",
                environment = myenv)

# %%
import azureml._restclient.snapshots_client
azureml._restclient.snapshots_client.SNAPSHOT_MAX_SIZE_BYTES = 3000000000

# %%
#running an experiment
new_run = new_experiment.submit(config=script_config)
new_run.wait_for_completion()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 #running an experiment
#       2 new_run = new_experiment.submit(config=script_config)
# ----> 3 new_run.wait_for_completion()
#
# File ~/Desktop/azure_pipeline/my_env/lib/python3.9/site-packages/azureml/core/run.py:869, in Run.wait_for_completion(self, show_output, wait_post_processing, raise_on_error)
#     867 poll_start_time = time.time()
#     868 while current_status is None or current_status in running_states:
# --> 869     time.sleep(Run._wait_before_polling(time.time() - poll_start_time))
#     870     current_status = self.get_status()
#     871     # add unknown status as running status
#
# KeyboardInterrupt:
